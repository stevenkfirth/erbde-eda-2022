# %% [markdown]
# # elec stacked demo

# %% [markdown]
# ## setup

# %%
import pandas as pd

# %% [markdown]
# ## 1 - data import

# %%
df=pd.read_csv('Elec - Stacked - 2005-2020.csv')
df
# Out:
#      year        gor         region  e7_meters  standard_meters  \
# 0    2005  E12000006           East      0.000            0.000
# 1    2005  E12000004  East Midlands      0.000            0.000
# 2    2005  E12000007         London      0.000            0.000
# 3    2005  E12000001     North East      0.000            0.000
# 4    2005  E12000002     North West      0.000            0.000
# ..    ...        ...            ...        ...              ...
# 146  2019  E12000006           East    684.012         2017.660
# 147  2019  E12000007         London    424.809         3206.913
# 148  2019  E12000008     South East    617.812         3337.166
# 149  2019  E12000009     South West    344.213         2244.334
# 150  2019  W92000004          Wales     91.664         1341.225
#
#      domestic_meters  non_domestic_meters  total_meters  e7_sales_gwh  \
# 0           2440.150              218.020      2658.170      0.000000
# ...

# %%
df.describe()
# Out:
#               year   e7_meters  standard_meters  domestic_meters  \
# count   151.000000  151.000000       151.000000       151.000000
# mean   2011.986755  209.784940      1122.873238      2463.527358
# std       4.323558  266.765591      1180.141991       781.601960
# min    2005.000000    0.000000         0.000000      1170.120000
# 25%    2008.000000    0.000000         0.000000      1997.670000
# 50%    2012.000000   72.249000      1151.108000      2414.510000
# 75%    2016.000000  393.477500      2107.452500      3138.678000
# max    2019.000000  854.310000      3337.166000      3954.978000
#
#        non_domestic_meters  total_meters  e7_sales_gwh  standard_sales_gwh  \
# count           151.000000    151.000000    151.000000          151.000000
# mean            220.581623   2684.108781   1108.489044         3985.915506
# std              90.910105    865.819643   1374.215922         4250.614355
# min              79.840000   1252.300000      0.000000            0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     151 non-null    int64
#  1   gor                      151 non-null    object
#  2   region                   151 non-null    object
#  3   e7_meters                151 non-null    float64
#  4   standard_meters          151 non-null    float64
#  5   domestic_meters          151 non-null    float64
#  6   non_domestic_meters      151 non-null    float64
#  7   total_meters             151 non-null    float64
#  8   e7_sales_gwh             151 non-null    float64
#  9   standard_sales_gwh       151 non-null    float64
#  10  domestic_sales_gwh       151 non-null    float64
#  11  non_domestic_sales_gwh   151 non-null    float64
#  12  total_gwh                151 non-null    float64
#  13  e7_mean_kwh              151 non-null    float64
# ...

# %%
df['all_mean_kwh']=df['all_mean_kwh'].str.replace(',','').astype(float).values

# %%
df
# Out:
#      year        gor         region  e7_meters  standard_meters  \
# 0    2005  E12000006           East      0.000            0.000
# 1    2005  E12000004  East Midlands      0.000            0.000
# 2    2005  E12000007         London      0.000            0.000
# 3    2005  E12000001     North East      0.000            0.000
# 4    2005  E12000002     North West      0.000            0.000
# ..    ...        ...            ...        ...              ...
# 146  2019  E12000006           East    684.012         2017.660
# 147  2019  E12000007         London    424.809         3206.913
# 148  2019  E12000008     South East    617.812         3337.166
# 149  2019  E12000009     South West    344.213         2244.334
# 150  2019  W92000004          Wales     91.664         1341.225
#
#      domestic_meters  non_domestic_meters  total_meters  e7_sales_gwh  \
# 0           2440.150              218.020      2658.170      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     151 non-null    int64
#  1   gor                      151 non-null    object
#  2   region                   151 non-null    object
#  3   e7_meters                151 non-null    float64
#  4   standard_meters          151 non-null    float64
#  5   domestic_meters          151 non-null    float64
#  6   non_domestic_meters      151 non-null    float64
#  7   total_meters             151 non-null    float64
#  8   e7_sales_gwh             151 non-null    float64
#  9   standard_sales_gwh       151 non-null    float64
#  10  domestic_sales_gwh       151 non-null    float64
#  11  non_domestic_sales_gwh   151 non-null    float64
#  12  total_gwh                151 non-null    float64
#  13  e7_mean_kwh              151 non-null    float64
# ...

# %%
df.groupby('year').sum()
# Out:
#       e7_meters  standard_meters  domestic_meters  non_domestic_meters  \
# year
# 2005      0.000            0.000        23246.693             2197.963
# 2006      0.000            0.000        23717.574             2205.804
# 2007      0.000            0.000        23916.278             2195.022
# 2008      0.000            0.000        24009.778             2168.425
# 2009      0.000            0.000        24246.877             2153.900
# 2010      0.000            0.000        27135.888             2357.270
# 2011      0.000            0.000        24488.168             2150.626
# 2012   4333.781        20266.163        24599.944             2159.693
# 2013   4235.634        20470.522        24706.146             2166.794
# 2014   4150.260        20722.530        24872.790             2229.180
# 2015   4036.790        20916.755        24953.545             2213.960
# 2016   3921.303        21299.399        25220.702             2233.899
# ...

# %%
df.columns
# Out:
# Index(['year', 'gor', 'region', 'e7_meters', 'standard_meters',
#        'domestic_meters', 'non_domestic_meters', 'total_meters',
#        'e7_sales_gwh', 'standard_sales_gwh', 'domestic_sales_gwh',
#        'non_domestic_sales_gwh', 'total_gwh', 'e7_mean_kwh', 'e7_median_kwh',
#        'standard_mean_kwh', 'standard_median_kwh', 'domestic_mean_kwh',
#        'domestic_median_kwh', 'non_domestic_mean_kwh',
#        'non_domestic_median_kwh', 'all_mean_kwh', 'all_median_kwh',
#        'avg_per_hhld_kwh'],
#       dtype='object')

# %%
df1=df.drop(columns='year')
df1
# Out:
#            gor         region  e7_meters  standard_meters  domestic_meters  \
# 0    E12000006           East      0.000            0.000         2440.150
# 1    E12000004  East Midlands      0.000            0.000         1911.400
# 2    E12000007         London      0.000            0.000         3248.590
# 3    E12000001     North East      0.000            0.000         1170.120
# 4    E12000002     North West      0.000            0.000         2910.570
# ..         ...            ...        ...              ...              ...
# 146  E12000006           East    684.012         2017.660         2701.672
# 147  E12000007         London    424.809         3206.913         3631.722
# 148  E12000008     South East    617.812         3337.166         3954.978
# 149  E12000009     South West    344.213         2244.334         2588.547
# 150  W92000004          Wales     91.664         1341.225         1432.889
#
# ...
