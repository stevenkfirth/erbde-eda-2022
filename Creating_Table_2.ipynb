# %% [markdown]
# # Table 2. Household characteristics of the 20 study homes.
#
# This notebook recreates Table 2 of the paper 'Heating behaviour in English homes: An assessment of indirect calculation methods'.
#
# The paper is available here: https://www.sciencedirect.com/science/article/pii/S0378778817314342

# %% [markdown]
# ## Setup

# %%
from lxml import etree
NS={'a':'http://www.refitsmarthomes.org'}
from collections import Counter
import pandas as pd

# %% [markdown]
# ## Step 1: Read in the data

# %%
filename=r'C:\Users\cvskf\OneDrive - Loughborough University\_Data\REFIT_Smart_Home_dataset_PUBLIC_v1\Data\REFIT_BUILDING_SURVEY.xml'
tree = etree.parse(filename)

# %%
tree

# %%
type(tree)
# Out:
# lxml.etree._ElementTree

# %%
print(etree.tostring(tree, pretty_print=True).decode())
# Out:
# <RefitXML xmlns="http://www.refitsmarthomes.org" id="REFIT1" startDateTime="2013-09-17T00:00:00Z">
# 	<Stock id="Stock1" comments="This stock contains the 20 homes studied in the REFIT project" startDateTime="2013-09-17T00:00:00Z" source="The REFIT project, www.refitsmarthomes.org">
# 		<Climate id="Climate1" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z" source="Loughborough University campus weather station" longitude="-1.2236" latitude="52.7692">
# 			<Sensor id="Sensor1247" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z">
# 				<TimeSeriesVariable id="TimeSeriesVariable1573" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z" variableType="Air temperature" units="Deg C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 			</Sensor>
# 			<Sensor id="Sensor1248" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z">
# 				<TimeSeriesVariable id="TimeSeriesVariable1574" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 			</Sensor>
# 			<Sensor id="Sensor1249" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z">
# 				<TimeSeriesVariable id="TimeSeriesVariable1575" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z" variableType="Wind speed" units="m/s" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 			</Sensor>
# 			<Sensor id="Sensor1250" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z">
# 				<TimeSeriesVariable id="TimeSeriesVariable1576" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z" variableType="Wind direction D1" units="Deg" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 			</Sensor>
# 			<Sensor id="Sensor1251" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z">
# 				<TimeSeriesVariable id="TimeSeriesVariable1577" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z" variableType="Wind direction SD1" units="Deg" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 			</Sensor>
# 			<Sensor id="Sensor1252" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z">
# 				<TimeSeriesVariable id="TimeSeriesVariable1578" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z" variableType="Average horizontal solar irradiance" units="kW/m^2" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 			</Sensor>
# 			<Sensor id="Sensor1253" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z">
# 				<TimeSeriesVariable id="TimeSeriesVariable1579" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z" variableType="Total horizontal solar irradiation" units="MJ/m^2" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 			</Sensor>
# 			<Sensor id="Sensor1254" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z">
# 				<TimeSeriesVariable id="TimeSeriesVariable1580" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z" variableType="NR_Wm2_Avg" units="W/m^2" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 			</Sensor>
# 			<Sensor id="Sensor1255" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z">
# 				<TimeSeriesVariable id="TimeSeriesVariable1581" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z" variableType="CNR_Wm2_Avg" units="W/m^2" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 			</Sensor>
# 			<Sensor id="Sensor1256" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z">
# 				<TimeSeriesVariable id="TimeSeriesVariable1582" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z" variableType="Total rainfall" units="mm" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 			</Sensor>
# 			<Sensor id="Sensor1257" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z">
# 				<TimeSeriesVariable id="TimeSeriesVariable1583" startDateTime="2013-11-04T09:15:00Z" endDateTime="2015-06-01T14:45:00Z" variableType="Average barometric pressure" units="hPa" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 			</Sensor>
# 		</Climate>
# 		<Building id="Building01" startDateTime="2013-10-01T00:00:00Z" occupancyType="Single family dwelling" builtFormType="Detached house or bungalow" orientation="327" wallTypeMainBuilding="Masonry-Boxwall-Cavity" wallAgeBandMainBuilding="1975 - 1980" cavityWallInsulationPresent="Yes" windowType="Double glazed - UPVC" loftType="Fully boarded" loftInsulationType="Mineral wool/fibre glass" loftInsulationThickness="300mm">
# 			<Household id="Household1" startDateTime="2013-10-01T00:00:00Z">
# 				<Person id="Person1" startDateTime="2013-10-01T00:00:00Z" sex="Male" ageBand="65-74" livesPermanemntlyAtHome="Yes" isHouseholdReferencePerson="Yes" employmentStatus="In full-time paid employment"/>
# 				<Person id="Person21" startDateTime="2013-10-01T00:00:00Z" sex="Female" ageBand="55-64" livesPermanemntlyAtHome="Yes"/>
# 			</Household>
# 			<Boiler id="Boiler1" startDateTime="2013-10-01T00:00:00Z" boilerType="Condensing" boilerAge="5" manufacturer="Baxi" model="BAXI PLATINUM 15 HE" fuelType="Gas" spaceIdRef="Space7">
# 				<BoilerControl id="BoilerControl1" startDateTime="2013-10-01T00:00:00Z" onOffControl="Yes" boilerThermostat="Yes" boilerTimer="Yes" manualOverride="Yes" zoneControl="No"/>
# 			</Boiler>
# 			<PhotovoltaicArray id="PhotovoltaicArray1" startDateTime="2013-10-01T00:00:00Z" ratingWp="3500"/>
# 			<Meter id="Meter1" startDateTime="2013-10-01T00:00:00Z" meterType="Gas">
# 				<Sensor id="Sensor1228" startDateTime="2013-09-14T00:00:00Z" endDateTime="2015-05-06T23:30:00Z" manufacturer="Smart Metering Solutions" model="Replacement gas meter">
# 					<TimeSeriesVariable id="TimeSeriesVariable1554" startDateTime="2013-09-14T00:00:00Z" endDateTime="2015-05-06T23:30:00Z" variableType="Gas volume" units="Cubic metres" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="Yes" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 			</Meter>
# 			<Meter id="Meter21" startDateTime="2013-10-01T00:00:00Z" meterType="Electric">
# 				<Sensor id="Sensor1258" startDateTime="2013-10-09T13:30:00Z" endDateTime="2015-07-10T12:00:00Z" manufacturer="CurrentCost" model="Mains clamp">
# 					<TimeSeriesVariable id="TimeSeriesVariable1584" startDateTime="2013-10-09T13:30:00Z" endDateTime="2015-07-10T12:00:00Z" variableType="Electrical power" units="W" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="Yes" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 			</Meter>
# 			<Space id="Space1" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="6.25" volume="14.375" storeyLevel="0" roomType="Study">
# 				<Sensor id="Sensor41" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:15:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable41" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor42" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T10:45:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable42" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T10:45:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor43" startDateTime="2014-06-18T11:00:00Z" endDateTime="2015-02-27T14:45:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable43" startDateTime="2014-06-18T11:00:00Z" endDateTime="2015-02-27T14:45:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor44" startDateTime="2015-02-27T15:00:00Z" endDateTime="2015-08-14T09:15:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable44" startDateTime="2015-02-27T15:00:00Z" endDateTime="2015-08-14T09:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 			</Space>
# 			<Space id="Space2" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="3.03" volume="6.969" storeyLevel="0" roomType="Hallway">
# 				<Sensor id="Sensor29" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:15:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable29" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor30" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T10:45:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable30" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T10:45:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor31" startDateTime="2014-06-18T11:00:00Z" endDateTime="2015-03-02T09:45:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable31" startDateTime="2014-06-18T11:00:00Z" endDateTime="2015-03-02T09:45:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor32" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-04-07T13:15:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable32" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-04-07T13:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor1294" startDateTime="2014-07-23T15:09:00Z" endDateTime="2015-04-28T13:13:00Z" manufacturer="RWE" model="Interior motion detector">
# 					<TimeSeriesVariable id="TimeSeriesVariable2111" startDateTime="2014-07-23T15:09:00Z" endDateTime="2015-04-28T13:13:00Z" variableType="Brightness" units="%" intervalType="VariableInterval" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable2193" startDateTime="2014-07-23T16:13:00Z" endDateTime="2015-04-28T11:43:00Z" variableType="Motion" intervalType="VariableInterval" repeatsOmitted="No" hasDuplicateTimestamps="Yes"/>
# 				</Sensor>
# 			</Space>
# 			<Space id="Space3" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="2.42" volume="5.566" storeyLevel="0" roomType="Stairs"/>
# 			<Space id="Space4" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="4.756802" volume="10.940644" storeyLevel="0" roomType="Cloakroom">
# 				<Sensor id="Sensor21" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:15:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable21" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor22" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T10:45:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable22" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T10:45:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor23" startDateTime="2014-06-18T11:00:00Z" endDateTime="2015-02-27T14:45:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable23" startDateTime="2014-06-18T11:00:00Z" endDateTime="2015-02-27T14:45:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor24" startDateTime="2015-02-27T15:00:00Z" endDateTime="2015-08-14T09:15:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable24" startDateTime="2015-02-27T15:00:00Z" endDateTime="2015-08-14T09:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 			</Space>
# 			<Space id="Space5" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="1.193198" volume="2.744356" storeyLevel="0" roomType="WC"/>
# 			<Space id="Space6" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="9.8" volume="22.54" storeyLevel="0" roomType="Kitchen">
# 				<Sensor id="Sensor33" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:30:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable33" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:30:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable432" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:30:00Z" variableType="Intensity" units="Lux" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable576" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:30:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor34" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable34" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable433" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" variableType="Intensity" units="Lux" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable577" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor35" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-02T09:30:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable35" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-02T09:30:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable434" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-03T15:30:00Z" variableType="Intensity" units="Lux" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable578" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-02T09:30:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor36" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-08-14T09:15:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable36" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-08-14T09:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable579" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-08-14T09:15:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor1291" startDateTime="2014-07-23T14:37:00Z" endDateTime="2015-04-28T12:38:00Z" manufacturer="RWE" model="Interior motion detector">
# 					<TimeSeriesVariable id="TimeSeriesVariable2108" startDateTime="2014-07-23T14:59:00Z" endDateTime="2015-04-28T12:38:00Z" variableType="Brightness" units="%" intervalType="VariableInterval" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable2190" startDateTime="2014-07-23T14:37:00Z" endDateTime="2015-04-28T11:33:00Z" variableType="Motion" intervalType="VariableInterval" repeatsOmitted="No" hasDuplicateTimestamps="Yes"/>
# 				</Sensor>
# 			</Space>
# 			<Space id="Space7" startDateTime="2013-10-01T00:00:00Z" conditionType="Not conditioned" area="8.014729" volume="17.962319" storeyLevel="0" roomType="Utility room">
# 				<Sensor id="Sensor1278" startDateTime="2014-07-22T15:28:00Z" endDateTime="2015-04-28T13:06:00Z" manufacturer="RWE" model="Exterior motion detector">
# 					<TimeSeriesVariable id="TimeSeriesVariable2084" startDateTime="2014-07-22T15:28:00Z" endDateTime="2015-04-28T13:06:00Z" variableType="Brightness" units="%" intervalType="VariableInterval" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable2097" startDateTime="2014-07-22T16:36:00Z" endDateTime="2015-04-28T11:33:00Z" variableType="Motion" intervalType="VariableInterval" repeatsOmitted="No" hasDuplicateTimestamps="Yes"/>
# 				</Sensor>
# 			</Space>
# 			<Space id="Space8" startDateTime="2013-10-01T00:00:00Z" conditionType="Not conditioned" area="12.87" volume="34.866651" storeyLevel="0" roomType="Conservatory">
# 				<Sensor id="Sensor25" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:15:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable25" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor26" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T10:45:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable26" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T10:45:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor27" startDateTime="2014-06-18T11:00:00Z" endDateTime="2015-02-27T14:45:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable27" startDateTime="2014-06-18T11:00:00Z" endDateTime="2015-02-27T14:45:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor28" startDateTime="2015-02-27T15:00:00Z" endDateTime="2015-08-14T09:15:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable28" startDateTime="2015-02-27T15:00:00Z" endDateTime="2015-08-14T09:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor1292" startDateTime="2014-07-23T14:52:00Z" endDateTime="2015-04-28T12:57:00Z" manufacturer="RWE" model="Interior motion detector">
# 					<TimeSeriesVariable id="TimeSeriesVariable2109" startDateTime="2014-07-23T14:52:00Z" endDateTime="2015-04-28T12:57:00Z" variableType="Brightness" units="%" intervalType="VariableInterval" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable2191" startDateTime="2014-07-23T15:47:00Z" endDateTime="2015-04-28T11:44:00Z" variableType="Motion" intervalType="VariableInterval" repeatsOmitted="No" hasDuplicateTimestamps="Yes"/>
# 				</Sensor>
# 			</Space>
# 			<Space id="Space9" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="23.76" volume="54.648" storeyLevel="0" roomType="Living room">
# 				<Sensor id="Sensor37" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:30:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable37" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:30:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable435" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:30:00Z" variableType="Intensity" units="Lux" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable580" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:30:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor38" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable38" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable436" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" variableType="Intensity" units="Lux" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable581" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor39" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-02T09:30:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable39" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-02T09:30:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable437" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-03T15:30:00Z" variableType="Intensity" units="Lux" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable582" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-02T09:30:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor40" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-08-14T09:15:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable40" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-08-14T09:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable583" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-08-14T09:15:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor1293" startDateTime="2014-07-23T14:37:00Z" endDateTime="2014-12-29T20:26:00Z" manufacturer="RWE" model="Interior motion detector">
# 					<TimeSeriesVariable id="TimeSeriesVariable2110" startDateTime="2014-07-23T15:29:00Z" endDateTime="2014-12-29T19:19:00Z" variableType="Brightness" units="%" intervalType="VariableInterval" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable2192" startDateTime="2014-07-23T14:37:00Z" endDateTime="2014-12-29T20:26:00Z" variableType="Motion" intervalType="VariableInterval" repeatsOmitted="No" hasDuplicateTimestamps="Yes"/>
# 				</Sensor>
# 			</Space>
# 			<Space id="Space10" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="8.75" volume="20.125" storeyLevel="1" roomType="Bedroom">
# 				<Sensor id="Sensor17" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:15:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable17" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor18" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T10:45:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable18" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T10:45:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor19" startDateTime="2014-06-18T11:00:00Z" endDateTime="2015-02-27T14:45:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable19" startDateTime="2014-06-18T11:00:00Z" endDateTime="2015-02-27T14:45:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor20" startDateTime="2015-02-27T15:00:00Z" endDateTime="2015-08-14T09:15:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable20" startDateTime="2015-02-27T15:00:00Z" endDateTime="2015-08-14T09:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 			</Space>
# 			<Space id="Space11" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="1.54" volume="9.108" storeyLevel="1" roomType="Stairs"/>
# 			<Space id="Space12" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="4.24" volume="9.752" storeyLevel="1" roomType="Landing"/>
# 			<Space id="Space13" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="4.75" volume="10.925" storeyLevel="1" roomType="Bathroom">
# 				<Sensor id="Sensor1" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:30:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable1" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:30:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable426" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:30:00Z" variableType="Intensity" units="Lux" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable567" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:30:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor2" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable2" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable427" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" variableType="Intensity" units="Lux" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable568" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor3" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-02T09:30:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable3" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-02T09:30:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable428" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-03T16:00:00Z" variableType="Intensity" units="Lux" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable569" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-02T09:30:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor4" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-08-14T09:15:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable4" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-08-14T09:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable570" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-08-14T09:15:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 			</Space>
# 			<Space id="Space14" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="6.65" volume="15.295" storeyLevel="1" roomType="Bedroom">
# 				<Sensor id="Sensor13" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:15:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable13" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor14" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T10:45:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable14" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T10:45:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor15" startDateTime="2014-06-18T11:00:00Z" endDateTime="2015-02-27T14:45:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable15" startDateTime="2014-06-18T11:00:00Z" endDateTime="2015-02-27T14:45:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor16" startDateTime="2015-02-27T15:00:00Z" endDateTime="2015-08-14T09:15:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable16" startDateTime="2015-02-27T15:00:00Z" endDateTime="2015-08-14T09:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 			</Space>
# 			<Space id="Space15" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="11.265973" volume="25.911737" storeyLevel="1" roomType="Bedroom">
# 				<Sensor id="Sensor5" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:09:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable5" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:09:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Second" intervalLength="1805" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable429" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:09:00Z" variableType="Intensity" units="Lux" intervalType="FixedInterval" intervalUnit="Second" intervalLength="1805" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable571" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:09:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Second" intervalLength="1805" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor6" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable6" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable430" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" variableType="Intensity" units="Lux" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable572" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T09:30:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor7" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-02T09:30:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable7" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-02T09:30:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable431" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-03T15:30:00Z" variableType="Intensity" units="Lux" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable573" startDateTime="2014-06-18T10:00:00Z" endDateTime="2015-03-02T09:30:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor8" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-08-14T09:00:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable8" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-08-14T09:00:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable574" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-08-14T09:00:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 			</Space>
# 			<Space id="Space16" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="0.954027" volume="2.194263" storeyLevel="1" roomType="Ensuite"/>
# 			<Space id="Space17" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="10.9" volume="25.07" storeyLevel="1" roomType="Bedroom">
# 				<Sensor id="Sensor9" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:15:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable9" startDateTime="2013-10-02T05:00:00Z" endDateTime="2013-12-03T15:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor10" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T10:45:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable10" startDateTime="2013-12-03T18:00:00Z" endDateTime="2014-06-18T10:45:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor11" startDateTime="2014-06-18T11:00:00Z" endDateTime="2015-03-02T09:45:00Z" manufacturer="Onset" model="Hobo pendant">
# 					<TimeSeriesVariable id="TimeSeriesVariable11" startDateTime="2014-06-18T11:00:00Z" endDateTime="2015-03-02T09:45:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor12" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-08-14T09:15:00Z" manufacturer="Onset" model="Hobo U12">
# 					<TimeSeriesVariable id="TimeSeriesVariable12" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-08-14T09:15:00Z" variableType="Air temperature" units="C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable575" startDateTime="2015-03-02T10:00:00Z" endDateTime="2015-08-14T09:15:00Z" variableType="Relative humidity" units="%" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="15" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 			</Space>
# 			<Space id="Space18" startDateTime="2013-10-01T00:00:00Z" conditionType="Heated" area="0.64" volume="1.472" storeyLevel="1" roomType="Hot water tank"/>
# 			<Space id="Space325" startDateTime="2013-10-01T00:00:00Z" conditionType="Not conditioned" area="52.11" volume="38.291303" storeyLevel="2" roomType="Loft"/>
# 			<Space id="Space346" startDateTime="2013-10-01T00:00:00Z" conditionType="Not conditioned" area="0.09" volume="0.207" storeyLevel="0" roomType="Wall"/>
# 			<Appliance id="Appliance1" startDateTime="2013-10-01T00:00:00Z" applianceType="Television" plugIdRef="Plug1" spaceIdRef="Space9"/>
# 			<Appliance id="Appliance2" startDateTime="2013-10-01T00:00:00Z" applianceType="Set top box" plugIdRef="Plug1" spaceIdRef="Space9"/>
# 			<Appliance id="Appliance3" startDateTime="2013-10-01T00:00:00Z" applianceType="DVD player/recorder" plugIdRef="Plug2" spaceIdRef="Space9"/>
# 			<Appliance id="Appliance4" startDateTime="2013-10-01T00:00:00Z" applianceType="HiFi" plugIdRef="Plug2" spaceIdRef="Space9"/>
# 			<Appliance id="Appliance5" startDateTime="2013-10-01T00:00:00Z" applianceType="Lamp" plugIdRef="Plug2" spaceIdRef="Space9"/>
# 			<Appliance id="Appliance6" startDateTime="2013-10-01T00:00:00Z" applianceType="Electric heater" plugIdRef="Plug3" spaceIdRef="Space8"/>
# 			<Appliance id="Appliance7" startDateTime="2013-10-01T00:00:00Z" applianceType="Fridge" plugIdRef="Plug4" spaceIdRef="Space6"/>
# 			<Appliance id="Appliance8" startDateTime="2013-10-01T00:00:00Z" applianceType="Dishwasher" plugIdRef="Plug5" spaceIdRef="Space6"/>
# 			<Appliance id="Appliance9" startDateTime="2013-10-01T00:00:00Z" applianceType="Toaster" plugIdRef="Plug6" spaceIdRef="Space6"/>
# 			<Appliance id="Appliance10" startDateTime="2013-10-01T00:00:00Z" applianceType="Coffee maker" plugIdRef="Plug7" spaceIdRef="Space6"/>
# 			<Appliance id="Appliance11" startDateTime="2013-10-01T00:00:00Z" applianceType="Coffee maker" plugIdRef="Plug8" spaceIdRef="Space6"/>
# 			<Appliance id="Appliance12" startDateTime="2013-10-01T00:00:00Z" applianceType="Kettle" plugIdRef="Plug32" spaceIdRef="Space6"/>
# 			<Appliance id="Appliance13" startDateTime="2013-10-01T00:00:00Z" applianceType="Freezer" plugIdRef="Plug10" spaceIdRef="Space7"/>
# 			<Appliance id="Appliance14" startDateTime="2013-10-01T00:00:00Z" applianceType="Washing machine" plugIdRef="Plug11" spaceIdRef="Space7"/>
# 			<Appliance id="Appliance15" startDateTime="2013-10-01T00:00:00Z" applianceType="Tumble dryer" plugIdRef="Plug12" spaceIdRef="Space7"/>
# 			<Appliance id="Appliance16" startDateTime="2013-10-01T00:00:00Z" applianceType="Electric heater" plugIdRef="Plug13" spaceIdRef="Space7"/>
# 			<Appliance id="Appliance17" startDateTime="2013-10-01T00:00:00Z" applianceType="DAB radio" plugIdRef="Plug9" spaceIdRef="Space6"/>
# 			<Appliance id="Appliance18" startDateTime="2013-10-01T00:00:00Z" applianceType="Desktop PC" plugIdRef="Plug14" spaceIdRef="Space1"/>
# 			<Appliance id="Appliance19" startDateTime="2013-10-01T00:00:00Z" applianceType="PC monitor" plugIdRef="Plug14" spaceIdRef="Space1"/>
# 			<Appliance id="Appliance20" startDateTime="2013-10-01T00:00:00Z" applianceType="Printer" plugIdRef="Plug15" spaceIdRef="Space1"/>
# 			<Appliance id="Appliance21" startDateTime="2013-10-01T00:00:00Z" applianceType="Router" plugIdRef="Plug16" spaceIdRef="Space1"/>
# 			<Appliance id="Appliance22" startDateTime="2013-10-01T00:00:00Z" applianceType="Electric heater" plugIdRef="Plug17" spaceIdRef="Space1"/>
# 			<Appliance id="Appliance23" startDateTime="2013-10-01T00:00:00Z" applianceType="Electric heater" plugIdRef="Plug18" spaceIdRef="Space1"/>
# 			<Appliance id="Appliance24" startDateTime="2013-10-01T00:00:00Z" applianceType="Shredder" plugIdRef="Plug19" spaceIdRef="Space1"/>
# 			<Appliance id="Appliance25" startDateTime="2013-10-01T00:00:00Z" applianceType="Freezer" plugIdRef="Plug20" spaceIdRef="Space4"/>
# 			<Appliance id="Appliance26" startDateTime="2013-10-01T00:00:00Z" applianceType="Lamp" plugIdRef="Plug21" spaceIdRef="Space15"/>
# 			<Appliance id="Appliance27" startDateTime="2013-10-01T00:00:00Z" applianceType="Lamp" plugIdRef="Plug22" spaceIdRef="Space15"/>
# 			<Appliance id="Appliance28" startDateTime="2013-10-01T00:00:00Z" applianceType="Alarm radio" plugIdRef="Plug22" spaceIdRef="Space15"/>
# 			<Appliance id="Appliance29" startDateTime="2013-10-01T00:00:00Z" applianceType="DAB radio" plugIdRef="Plug23" spaceIdRef="Space17"/>
# 			<Appliance id="Appliance30" startDateTime="2013-10-01T00:00:00Z" applianceType="Lamp" plugIdRef="Plug21" spaceIdRef="Space15"/>
# 			<Appliance id="Appliance31" startDateTime="2013-10-01T00:00:00Z" applianceType="Lava lamp" plugIdRef="Plug24" spaceIdRef="Space17"/>
# 			<Appliance id="Appliance32" startDateTime="2013-10-01T00:00:00Z" applianceType="CD player" plugIdRef="Plug25" spaceIdRef="Space17"/>
# 			<Appliance id="Appliance33" startDateTime="2013-10-01T00:00:00Z" applianceType="Lamp" plugIdRef="Plug26" spaceIdRef="Space14"/>
# 			<Appliance id="Appliance34" startDateTime="2013-10-01T00:00:00Z" applianceType="CD player" plugIdRef="Plug27" spaceIdRef="Space14"/>
# 			<Appliance id="Appliance35" startDateTime="2013-10-01T00:00:00Z" applianceType="Television" plugIdRef="Plug28" spaceIdRef="Space10"/>
# 			<Appliance id="Appliance36" startDateTime="2013-10-01T00:00:00Z" applianceType="Video player" plugIdRef="Plug29" spaceIdRef="Space10"/>
# ...
# 				</Sensor>
# 				<Sensor id="Sensor862" startDateTime="2014-08-21T14:00:01Z" endDateTime="2015-02-08T04:30:01Z" manufacturer="Maxim" model="iButton">
# 					<TimeSeriesVariable id="TimeSeriesVariable1168" startDateTime="2014-08-21T14:00:01Z" endDateTime="2015-02-08T04:30:01Z" variableType="Surface temperature" units="degrees C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="Yes"/>
# 				</Sensor>
# 			</Radiator>
# 			<Radiator id="Radiator251" startDateTime="2014-02-07T00:00:00Z" length="0.6" height="0.6" spaceIdRef="Space321">
# 				<RadiatorValve id="RadiatorValve367" startDateTime="2014-09-26T16:00:00Z" endDateTime="2015-04-28T12:47:00Z" radiatorValveType="Programmable wireless thermostatic radiator valve" manufacturer="RWE" model="TRV">
# 					<TimeSeriesVariable id="TimeSeriesVariable1783" startDateTime="2014-09-26T16:00:00Z" endDateTime="2015-04-28T12:42:00Z" variableType="Actual temperature" units="degrees C" intervalType="VariableInterval" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable1933" startDateTime="2014-09-26T16:25:00Z" endDateTime="2015-04-28T12:47:00Z" variableType="Air humidity" units="%" intervalType="VariableInterval" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 					<TimeSeriesVariable id="TimeSeriesVariable2083" startDateTime="2014-09-26T17:06:00Z" endDateTime="2015-04-28T08:30:00Z" variableType="Nominal temperature" units="degrees C" intervalType="VariableInterval" repeatsOmitted="No" hasDuplicateTimestamps="Yes"/>
# 				</RadiatorValve>
# 				<Sensor id="Sensor863" startDateTime="2014-02-08T06:00:01Z" endDateTime="2014-07-28T22:30:01Z" manufacturer="Maxim" model="iButton">
# 					<TimeSeriesVariable id="TimeSeriesVariable1169" startDateTime="2014-02-08T06:00:01Z" endDateTime="2014-07-28T22:30:01Z" variableType="Surface temperature" units="degrees C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="Yes" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 				<Sensor id="Sensor864" startDateTime="2014-08-21T14:00:01Z" endDateTime="2015-02-06T14:00:01Z" manufacturer="Maxim" model="iButton">
# 					<TimeSeriesVariable id="TimeSeriesVariable1170" startDateTime="2014-08-21T14:00:01Z" endDateTime="2015-02-06T14:00:01Z" variableType="Surface temperature" units="degrees C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="No" repeatsOmitted="No" hasDuplicateTimestamps="Yes"/>
# 				</Sensor>
# 				<Sensor id="Sensor865" startDateTime="2015-02-06T14:00:01Z" endDateTime="2015-07-13T14:30:01Z" manufacturer="Maxim" model="iButton">
# 					<TimeSeriesVariable id="TimeSeriesVariable1171" startDateTime="2015-02-06T14:00:01Z" endDateTime="2015-07-13T14:30:01Z" variableType="Surface temperature" units="degrees C" intervalType="FixedInterval" intervalUnit="Minute" intervalLength="30" hasMissingData="Yes" repeatsOmitted="No" hasDuplicateTimestamps="No"/>
# 				</Sensor>
# 			</Radiator>
# 			<RoomThermostat id="RoomThermostat17" startDateTime="2014-02-07T00:00:00Z" endDateTime="2015-01-23T00:00:00Z" roomThermostatType="Manual" spaceIdRef="Space315"/>
# 			<RoomThermostat id="RoomThermostat32" startDateTime="2015-01-23T00:00:00Z" roomThermostatType="Smart" manufacturer="British Gas" model="Hive"/>
# 			<Surface id="Surface1" surfaceType="External floor" innerSpaceIdRef="Space312" azimuth="0" tilt="180" area="17.92"/>
# 			<Surface id="Surface2" surfaceType="Internal ceiling" innerSpaceIdRef="Space312" outerSpaceIdRef="Space317" azimuth="0" tilt="0" area="4.4"/>
# 			<Surface id="Surface3" surfaceType="Internal ceiling" innerSpaceIdRef="Space312" outerSpaceIdRef="Space318" azimuth="0" tilt="0" area="12.32"/>
# 			<Surface id="Surface4" surfaceType="Internal ceiling" innerSpaceIdRef="Space312" outerSpaceIdRef="Space322" azimuth="0" tilt="0" area="1.2"/>
# 			<Surface id="Surface5" surfaceType="External wall" innerSpaceIdRef="Space312" azimuth="0" tilt="90" area="3.9">
# 				<Opening id="Opening1" openingType="Door" area="3.78"/>
# 			</Surface>
# 			<Surface id="Surface6" surfaceType="Internal wall" innerSpaceIdRef="Space312" outerSpaceIdRef="Space313" azimuth="90" tilt="90" area="3.6"/>
# 			<Surface id="Surface7" surfaceType="Internal wall" innerSpaceIdRef="Space312" outerSpaceIdRef="Space315" azimuth="90" tilt="90" area="1.2">
# 				<Opening id="Opening1" openingType="Door" area="1.68"/>
# 			</Surface>
# 			<Surface id="Surface8" surfaceType="Internal wall" innerSpaceIdRef="Space312" outerSpaceIdRef="Space316" azimuth="90" tilt="90" area="6.96"/>
# 			<Surface id="Surface9" surfaceType="External wall" innerSpaceIdRef="Space312" azimuth="180" tilt="90" area="4.98">
# 				<Opening id="Opening1" openingType="Window" area="0.36"/>
# 				<Opening id="Opening2" openingType="Window" area="0.36"/>
# 				<Opening id="Opening3" openingType="Window" area="0.99"/>
# 				<Opening id="Opening4" openingType="Window" area="0.99"/>
# 			</Surface>
# 			<Surface id="Surface10" surfaceType="External wall" innerSpaceIdRef="Space312" azimuth="270" tilt="90" area="13.44"/>
# 			<Surface id="Surface11" surfaceType="External floor" innerSpaceIdRef="Space313" azimuth="0" tilt="180" area="2.7"/>
# 			<Surface id="Surface12" surfaceType="Internal ceiling" innerSpaceIdRef="Space313" outerSpaceIdRef="Space319" azimuth="0" tilt="0" area="2.7"/>
# 			<Surface id="Surface13" surfaceType="External wall" innerSpaceIdRef="Space313" azimuth="0" tilt="90" area="3.78">
# 				<Opening id="Opening1" openingType="Window" area="0.54"/>
# 			</Surface>
# 			<Surface id="Surface14" surfaceType="Internal wall" innerSpaceIdRef="Space313" outerSpaceIdRef="Space314" azimuth="90" tilt="90" area="3.6"/>
# 			<Surface id="Surface15" surfaceType="Internal wall" innerSpaceIdRef="Space313" outerSpaceIdRef="Space315" azimuth="180" tilt="90" area="0.480000000000001">
# 				<Opening id="Opening1" openingType="Door" area="1.68"/>
# 			</Surface>
# 			<Surface id="Surface16" surfaceType="Internal wall" innerSpaceIdRef="Space313" outerSpaceIdRef="Space316" azimuth="180" tilt="90" area="2.16"/>
# 			<Surface id="Surface17" surfaceType="External floor" innerSpaceIdRef="Space314" azimuth="0" tilt="180" area="8.4"/>
# 			<Surface id="Surface18" surfaceType="Internal ceiling" innerSpaceIdRef="Space314" outerSpaceIdRef="Space319" azimuth="0" tilt="0" area="0.57"/>
# 			<Surface id="Surface19" surfaceType="Internal ceiling" innerSpaceIdRef="Space314" outerSpaceIdRef="Space320" azimuth="0" tilt="0" area="7.83"/>
# 			<Surface id="Surface20" surfaceType="External wall" innerSpaceIdRef="Space314" azimuth="0" tilt="90" area="5.52">
# 				<Opening id="Opening1" openingType="Window" area="1.2"/>
# 			</Surface>
# 			<Surface id="Surface21" surfaceType="External wall" innerSpaceIdRef="Space314" azimuth="90" tilt="90" area="5.31">
# 				<Opening id="Opening1" openingType="Door" area="1.89"/>
# 			</Surface>
# 			<Surface id="Surface22" surfaceType="Internal wall" innerSpaceIdRef="Space314" outerSpaceIdRef="Space315" azimuth="180" tilt="90" area="4.2">
# 				<Opening id="Opening1" openingType="Air" area="2.52"/>
# 			</Surface>
# 			<Surface id="Surface23" surfaceType="Internal wall" innerSpaceIdRef="Space314" outerSpaceIdRef="Space315" azimuth="270" tilt="90" area="3.6"/>
# 			<Surface id="Surface24" surfaceType="External floor" innerSpaceIdRef="Space315" azimuth="0" tilt="180" area="12.05"/>
# 			<Surface id="Surface25" surfaceType="Internal ceiling" innerSpaceIdRef="Space315" outerSpaceIdRef="Space319" azimuth="0" tilt="0" area="0.36"/>
# 			<Surface id="Surface26" surfaceType="Internal ceiling" innerSpaceIdRef="Space315" outerSpaceIdRef="Space322" azimuth="0" tilt="0" area="4.41"/>
# 			<Surface id="Surface27" surfaceType="Internal ceiling" innerSpaceIdRef="Space315" outerSpaceIdRef="Space321" azimuth="0" tilt="0" area="7.28"/>
# 			<Surface id="Surface28" surfaceType="External wall" innerSpaceIdRef="Space315" azimuth="90" tilt="90" area="6.24"/>
# 			<Surface id="Surface29" surfaceType="External wall" innerSpaceIdRef="Space315" azimuth="180" tilt="90" area="7.35">
# 				<Opening id="Opening1" openingType="Door" area="1.89"/>
# 				<Opening id="Opening2" openingType="Window" area="1.32"/>
# 				<Opening id="Opening3" openingType="Window" area="0.48"/>
# 			</Surface>
# 			<Surface id="Surface30" surfaceType="Internal wall" innerSpaceIdRef="Space315" outerSpaceIdRef="Space316" azimuth="0" tilt="90" area="0">
# 				<Opening id="Opening1" openingType="Air" area="2.16"/>
# 			</Surface>
# 			<Surface id="Surface31" surfaceType="Internal wall" innerSpaceIdRef="Space315" outerSpaceIdRef="Space316" azimuth="270" tilt="90" area="6.96"/>
# 			<Surface id="Surface32" surfaceType="External floor" innerSpaceIdRef="Space316" azimuth="0" tilt="180" area="2.61"/>
# 			<Surface id="Surface33" surfaceType="Internal ceiling" innerSpaceIdRef="Space316" outerSpaceIdRef="Space319" azimuth="0" tilt="0" area="0.359999999999999"/>
# 			<Surface id="Surface34" surfaceType="Internal ceiling" innerSpaceIdRef="Space316" outerSpaceIdRef="Space323" azimuth="0" tilt="0" area="0">
# 				<Opening id="Opening1" openingType="Air" area="2.25"/>
# 			</Surface>
# 			<Surface id="Surface35" surfaceType="Internal ceiling" innerSpaceIdRef="Space317" outerSpaceIdRef="Space386" azimuth="0" tilt="0" area="4.4"/>
# 			<Surface id="Surface36" surfaceType="Internal wall" innerSpaceIdRef="Space317" outerSpaceIdRef="Space318" azimuth="0" tilt="90" area="5.28"/>
# 			<Surface id="Surface37" surfaceType="Internal wall" innerSpaceIdRef="Space317" outerSpaceIdRef="Space318" azimuth="90" tilt="90" area="1.92"/>
# 			<Surface id="Surface38" surfaceType="Internal wall" innerSpaceIdRef="Space317" outerSpaceIdRef="Space322" azimuth="90" tilt="90" area="1.2">
# 				<Opening id="Opening1" openingType="Door" area="1.68"/>
# 			</Surface>
# 			<Surface id="Surface39" surfaceType="External wall" innerSpaceIdRef="Space317" azimuth="180" tilt="90" area="3.84">
# 				<Opening id="Opening1" openingType="Window" area="1.44"/>
# 			</Surface>
# 			<Surface id="Surface40" surfaceType="External wall" innerSpaceIdRef="Space317" azimuth="270" tilt="90" area="4.8"/>
# 			<Surface id="Surface41" surfaceType="Internal ceiling" innerSpaceIdRef="Space318" outerSpaceIdRef="Space386" azimuth="0" tilt="0" area="12.32"/>
# 			<Surface id="Surface42" surfaceType="External wall" innerSpaceIdRef="Space318" azimuth="270" tilt="90" area="8.64"/>
# 			<Surface id="Surface43" surfaceType="External wall" innerSpaceIdRef="Space318" azimuth="0" tilt="90" area="5.52">
# 				<Opening id="Opening1" openingType="Window" area="1.08"/>
# 				<Opening id="Opening2" openingType="Window" area="1.08"/>
# 			</Surface>
# 			<Surface id="Surface44" surfaceType="Internal wall" innerSpaceIdRef="Space318" outerSpaceIdRef="Space319" azimuth="90" tilt="90" area="4.56"/>
# 			<Surface id="Surface45" surfaceType="Internal wall" innerSpaceIdRef="Space318" outerSpaceIdRef="Space323" azimuth="90" tilt="90" area="6"/>
# 			<Surface id="Surface46" surfaceType="Internal wall" innerSpaceIdRef="Space318" outerSpaceIdRef="Space322" azimuth="180" tilt="90" area="0.719999999999999">
# 				<Opening id="Opening1" openingType="Door" area="1.68"/>
# 			</Surface>
# 			<Surface id="Surface47" surfaceType="Internal ceiling" innerSpaceIdRef="Space319" outerSpaceIdRef="Space386" azimuth="0" tilt="0" area="3.99"/>
# 			<Surface id="Surface48" surfaceType="External wall" innerSpaceIdRef="Space319" azimuth="0" tilt="90" area="4.23">
# 				<Opening id="Opening1" openingType="Window" area="0.81"/>
# 			</Surface>
# 			<Surface id="Surface49" surfaceType="Internal wall" innerSpaceIdRef="Space319" outerSpaceIdRef="Space320" azimuth="90" tilt="90" area="4.56"/>
# 			<Surface id="Surface50" surfaceType="Internal wall" innerSpaceIdRef="Space319" outerSpaceIdRef="Space323" azimuth="180" tilt="90" area="2.16"/>
# 			<Surface id="Surface51" surfaceType="Internal wall" innerSpaceIdRef="Space319" outerSpaceIdRef="Space322" azimuth="180" tilt="90" area="0.480000000000001">
# 				<Opening id="Opening1" openingType="Door" area="1.68"/>
# 			</Surface>
# 			<Surface id="Surface52" surfaceType="Internal wall" innerSpaceIdRef="Space319" outerSpaceIdRef="Space320" azimuth="180" tilt="90" area="0.72"/>
# 			<Surface id="Surface53" surfaceType="Internal ceiling" innerSpaceIdRef="Space323" outerSpaceIdRef="Space386" azimuth="0" tilt="0" area="2.25"/>
# 			<Surface id="Surface54" surfaceType="Internal wall" innerSpaceIdRef="Space323" outerSpaceIdRef="Space322" azimuth="90" tilt="90" area="0">
# 				<Opening id="Opening1" openingType="Air" area="6"/>
# 			</Surface>
# 			<Surface id="Surface55" surfaceType="Internal wall" innerSpaceIdRef="Space323" outerSpaceIdRef="Space322" azimuth="180" tilt="90" area="0">
# 				<Opening id="Opening1" openingType="Air" area="2.16"/>
# 			</Surface>
# 			<Surface id="Surface56" surfaceType="Internal ceiling" innerSpaceIdRef="Space322" outerSpaceIdRef="Space386" azimuth="0" tilt="0" area="5.61"/>
# 			<Surface id="Surface57" surfaceType="Internal wall" innerSpaceIdRef="Space322" outerSpaceIdRef="Space320" azimuth="90" tilt="90" area="0.96">
# 				<Opening id="Opening1" openingType="Door" area="1.68"/>
# 			</Surface>
# 			<Surface id="Surface58" surfaceType="Internal wall" innerSpaceIdRef="Space322" outerSpaceIdRef="Space321" azimuth="90" tilt="90" area="4.56">
# 				<Opening id="Opening1" openingType="Door" area="1.68"/>
# 			</Surface>
# 			<Surface id="Surface59" surfaceType="External wall" innerSpaceIdRef="Space322" azimuth="180" tilt="90" area="5.52">
# 				<Opening id="Opening1" openingType="Window" area="1.2"/>
# 			</Surface>
# 			<Surface id="Surface60" surfaceType="Internal ceiling" innerSpaceIdRef="Space320" outerSpaceIdRef="Space386" azimuth="0" tilt="0" area="7.83"/>
# 			<Surface id="Surface61" surfaceType="External wall" innerSpaceIdRef="Space320" azimuth="0" tilt="90" area="4.56">
# 				<Opening id="Opening1" openingType="Window" area="1.44"/>
# 			</Surface>
# 			<Surface id="Surface62" surfaceType="External wall" innerSpaceIdRef="Space320" azimuth="90" tilt="90" area="7.2"/>
# 			<Surface id="Surface63" surfaceType="Internal wall" innerSpaceIdRef="Space320" outerSpaceIdRef="Space321" azimuth="180" tilt="90" area="6.72"/>
# 			<Surface id="Surface64" surfaceType="Internal ceiling" innerSpaceIdRef="Space321" outerSpaceIdRef="Space386" azimuth="0" tilt="0" area="7.28"/>
# 			<Surface id="Surface65" surfaceType="External wall" innerSpaceIdRef="Space321" azimuth="90" tilt="90" area="6.24"/>
# 			<Surface id="Surface66" surfaceType="External wall" innerSpaceIdRef="Space321" azimuth="180" tilt="90" area="5.28">
# 				<Opening id="Opening1" openingType="Window" area="1.44"/>
# 			</Surface>
# 			<Surface id="Surface67" surfaceType="External wall" innerSpaceIdRef="Space386" azimuth="270" tilt="90" area="5.4896268"/>
# 			<Surface id="Surface68" surfaceType="External roof" innerSpaceIdRef="Space386" azimuth="0" tilt="35" area="26.6617165399006"/>
# 			<Surface id="Surface69" surfaceType="External roof" innerSpaceIdRef="Space386" azimuth="180" tilt="35" area="26.6617165399006"/>
# 			<Surface id="Surface70" surfaceType="External wall" innerSpaceIdRef="Space386" azimuth="90" tilt="90" area="5.4896268"/>
# 			<Sensor id="Sensor1427" startDateTime="2014-09-26T17:13:00Z" endDateTime="2015-04-28T08:59:00Z" manufacturer="RWE" model="Contact sensor">
# 				<TimeSeriesVariable id="TimeSeriesVariable2323" startDateTime="2014-09-26T17:13:00Z" endDateTime="2015-04-28T08:59:00Z" variableType="Open/Closed" intervalType="VariableInterval" repeatsOmitted="No" hasDuplicateTimestamps="Yes"/>
# 			</Sensor>
# 			<Sensor id="Sensor1428" startDateTime="2014-09-26T17:09:00Z" endDateTime="2015-04-26T19:46:00Z" manufacturer="RWE" model="Contact sensor">
# 				<TimeSeriesVariable id="TimeSeriesVariable2324" startDateTime="2014-09-26T17:09:00Z" endDateTime="2015-04-26T19:46:00Z" variableType="Open/Closed" intervalType="VariableInterval" repeatsOmitted="No" hasDuplicateTimestamps="Yes"/>
# 			</Sensor>
# 		</Building>
# 	</Stock>
# </RefitXML>

# %% [markdown]
# ## Step 2: Clean and/or process the data

# %% [markdown]
# ## Step 3: Analyse the data

# %% [markdown]
# ### What is the distribution of house type in the 20 buildings?

# %%
xpath_query_string='//a:Building'
buildings=tree.getroot().xpath(xpath_query_string,namespaces=NS)
buildings
# Out:
# [<Element {http://www.refitsmarthomes.org}Building at 0x240a40ebd80>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a41000c0>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a4106900>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a410ebc0>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a411bac0>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a41268c0>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a4130e00>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a4137a00>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a413ee00>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a4146c00>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a414efc0>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a4156e40>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a415dd40>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a4167bc0>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a416d980>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a4178600>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a417f340>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a4186680>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a418d3c0>,
#  <Element {http://www.refitsmarthomes.org}Building at 0x240a4194940>]

# %%
result=[]
for building in buildings:
    result.append(building.get('builtFormType'))
result
# Out:
# ['Detached house or bungalow',
#  'Semi detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Mid terrace house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Semi detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Semi detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow']

# %%
result=[building.get('builtFormType') for building in buildings]  # list comprehension
result
# Out:
# ['Detached house or bungalow',
#  'Semi detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Mid terrace house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Semi detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Semi detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow']

# %%
xpath_query_string='//a:Building/@builtFormType'
result=tree.getroot().xpath(xpath_query_string,namespaces=NS)
result
# Out:
# ['Detached house or bungalow',
#  'Semi detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Mid terrace house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Semi detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow',
#  'Semi detached house or bungalow',
#  'Detached house or bungalow',
#  'Detached house or bungalow']

# %%
house_type_distribution=Counter(result)
house_type_distribution
# Out:
# Counter({'Detached house or bungalow': 16,
#          'Semi detached house or bungalow': 3,
#          'Mid terrace house or bungalow': 1})

# %% [markdown]
# ... in a single code cell...

# %%
xpath_query_string='//a:Building/@builtFormType'
result=tree.getroot().xpath(xpath_query_string,namespaces=NS)
house_type_distribution=Counter(result)
house_type_distribution
# Out:
# Counter({'Detached house or bungalow': 16,
#          'Semi detached house or bungalow': 3,
#          'Mid terrace house or bungalow': 1})

# %%
house_type_distribution['Mid terrace house or bungalow']
# Out:
# 1

# %% [markdown]
# ## Step 4: Output the graphs and tables

# %% [markdown]
# ### Creating Table 2

# %%
index=pd.Index(['House type','Construction type'],name='Characteristic')
df=pd.DataFrame(index=index,
                data={'Description':[f'Detached ({house_type_distribution["Detached house or bungalow"]}), semi-detached ({house_type_distribution["Semi detached house or bungalow"]}), mid-terrace ({house_type_distribution["Mid terrace house or bungalow"]})',
                                     'test'
                                    ]})
df
# Out:
#                                                          Description
# Characteristic
# House type         Detached (16), semi-detached (3), mid-terrace (1)
# Construction type                                               test

# %%
df.to_csv('Table2.csv')
